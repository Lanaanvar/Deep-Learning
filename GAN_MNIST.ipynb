# %% [markdown]
# <a href="https://colab.research.google.com/github/Lanaanvar/Deep-Learning/blob/main/GAN_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torchvision.utils import save_image, make_grid
import os

# Hyperparameters
latent_dim = 100
img_shape = (1, 28, 28)
batch_size = 64
epochs = 50
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Create directory to save generated images
os.makedirs("gan_images", exist_ok=True)

# MNIST dataset loader
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])  # scale between [-1, 1]
])

dataloader = DataLoader(
    datasets.MNIST(root='.', train=True, download=True, transform=transform),
    batch_size=batch_size, shuffle=True
)

# Generator Model
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.LeakyReLU(0.2),
            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 784),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        return img.view(z.size(0), *img_shape)

# Discriminator Model
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(784, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, img):
        flat = img.view(img.size(0), -1)
        return self.model(flat)

# Instantiate models
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# Loss and optimizers
criterion = nn.BCELoss()
optimizer_G = optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizer_D = optim.Adam(discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))

# Training Loop
for epoch in range(epochs):
    for i, (imgs, _) in enumerate(dataloader):
        batch_size = imgs.size(0)
        real_imgs = imgs.to(device)

        # Real and fake labels
        valid = torch.ones(batch_size, 1).to(device)
        fake = torch.zeros(batch_size, 1).to(device)

        # ---------------------
        #  Train Generator
        # ---------------------
        optimizer_G.zero_grad()

        z = torch.randn(batch_size, latent_dim).to(device)
        gen_imgs = generator(z)

        g_loss = criterion(discriminator(gen_imgs), valid)
        g_loss.backward()
        optimizer_G.step()

        # ---------------------
        #  Train Discriminator
        # ---------------------
        optimizer_D.zero_grad()

        real_loss = criterion(discriminator(real_imgs), valid)
        fake_loss = criterion(discriminator(gen_imgs.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2

        d_loss.backward()
        optimizer_D.step()

        if i % 200 == 0:
            print(f"Epoch [{epoch}/{epochs}] Batch [{i}/{len(dataloader)}] \
                  Loss D: {d_loss.item():.4f}, Loss G: {g_loss.item():.4f}")

    # Save generated samples each epoch
    with torch.no_grad():
        z = torch.randn(64, latent_dim).to(device)
        generated = generator(z)
        grid = make_grid(generated, nrow=8, normalize=True)
        save_image(grid, f"gan_images/epoch_{epoch+1}.png")

print("🎉 Training complete. Check 'gan_images/' for generated digits.")
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 16.0MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 487kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.46MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 6.94MB/s]
# Epoch [0/50] Batch [0/938]                   Loss D: 0.6876, Loss G: 0.7098
# Epoch [0/50] Batch [200/938]                   Loss D: 0.5805, Loss G: 0.6060
# Epoch [0/50] Batch [400/938]                   Loss D: 0.5649, Loss G: 1.3251
# Epoch [0/50] Batch [600/938]                   Loss D: 0.4564, Loss G: 1.2234
# Epoch [0/50] Batch [800/938]                   Loss D: 0.4717, Loss G: 0.9241
# Epoch [1/50] Batch [0/938]                   Loss D: 0.6011, Loss G: 0.4539
# Epoch [1/50] Batch [200/938]                   Loss D: 0.5128, Loss G: 0.5760
# Epoch [1/50] Batch [400/938]                   Loss D: 0.6061, Loss G: 0.5210
# Epoch [1/50] Batch [600/938]                   Loss D: 0.5292, Loss G: 1.5544
# Epoch [1/50] Batch [800/938]                   Loss D: 0.4831, Loss G: 0.9838
# Epoch [2/50] Batch [0/938]                   Loss D: 0.4915, Loss G: 1.7939
# Epoch [2/50] Batch [200/938]                   Loss D: 0.4932, Loss G: 0.8531
# Epoch [2/50] Batch [400/938]                   Loss D: 0.5156, Loss G: 0.9378
# Epoch [2/50] Batch [600/938]                   Loss D: 0.4572, Loss G: 0.7567
# Epoch [2/50] Batch [800/938]                   Loss D: 0.5457, Loss G: 0.6313
# Epoch [3/50] Batch [0/938]                   Loss D: 0.4343, Loss G: 1.2912
# Epoch [3/50] Batch [200/938]                   Loss D: 0.3537, Loss G: 1.2256
# Epoch [3/50] Batch [400/938]                   Loss D: 0.5705, Loss G: 2.5179
# Epoch [3/50] Batch [600/938]                   Loss D: 0.6330, Loss G: 2.4574
# Epoch [3/50] Batch [800/938]                   Loss D: 0.6082, Loss G: 0.5370
# Epoch [4/50] Batch [0/938]                   Loss D: 0.4503, Loss G: 0.8884
# Epoch [4/50] Batch [200/938]                   Loss D: 0.5551, Loss G: 0.6350
# Epoch [4/50] Batch [400/938]                   Loss D: 0.3543, Loss G: 1.8207
# Epoch [4/50] Batch [600/938]                   Loss D: 0.3879, Loss G: 1.5836
# Epoch [4/50] Batch [800/938]                   Loss D: 0.7139, Loss G: 2.7074
# Epoch [5/50] Batch [0/938]                   Loss D: 0.4629, Loss G: 0.8775
# Epoch [5/50] Batch [200/938]                   Loss D: 0.4346, Loss G: 1.5427
# Epoch [5/50] Batch [400/938]                   Loss D: 0.5727, Loss G: 1.7999
# Epoch [5/50] Batch [600/938]                   Loss D: 0.4784, Loss G: 1.1435
# Epoch [5/50] Batch [800/938]                   Loss D: 0.5205, Loss G: 1.5551
# Epoch [6/50] Batch [0/938]                   Loss D: 0.7094, Loss G: 0.4111
# Epoch [6/50] Batch [200/938]                   Loss D: 0.5086, Loss G: 0.9447
# Epoch [6/50] Batch [400/938]                   Loss D: 0.6529, Loss G: 0.4852
# Epoch [6/50] Batch [600/938]                   Loss D: 0.7292, Loss G: 2.0001
# Epoch [6/50] Batch [800/938]                   Loss D: 0.5112, Loss G: 1.0213
# Epoch [7/50] Batch [0/938]                   Loss D: 0.4732, Loss G: 1.1926
# Epoch [7/50] Batch [200/938]                   Loss D: 0.5734, Loss G: 0.7088
# Epoch [7/50] Batch [400/938]                   Loss D: 0.5364, Loss G: 1.3670
# Epoch [7/50] Batch [600/938]                   Loss D: 0.5186, Loss G: 1.2141
# Epoch [7/50] Batch [800/938]                   Loss D: 0.6618, Loss G: 0.4817
# Epoch [8/50] Batch [0/938]                   Loss D: 0.5575, Loss G: 1.5114
# Epoch [8/50] Batch [200/938]                   Loss D: 0.5108, Loss G: 1.3338
# Epoch [8/50] Batch [400/938]                   Loss D: 0.5579, Loss G: 0.8118
# Epoch [8/50] Batch [600/938]                   Loss D: 0.6104, Loss G: 0.6789
# Epoch [8/50] Batch [800/938]                   Loss D: 0.6387, Loss G: 1.9136
# Epoch [9/50] Batch [0/938]                   Loss D: 0.5125, Loss G: 1.0694
# Epoch [9/50] Batch [200/938]                   Loss D: 0.6049, Loss G: 0.6558
# Epoch [9/50] Batch [400/938]                   Loss D: 0.5462, Loss G: 0.8975
# Epoch [9/50] Batch [600/938]                   Loss D: 0.5565, Loss G: 1.0124
# Epoch [9/50] Batch [800/938]                   Loss D: 0.5343, Loss G: 1.0224
# Epoch [10/50] Batch [0/938]                   Loss D: 0.6611, Loss G: 1.1825
# Epoch [10/50] Batch [200/938]                   Loss D: 0.5893, Loss G: 1.3773
# Epoch [10/50] Batch [400/938]                   Loss D: 0.5437, Loss G: 0.8749
# Epoch [10/50] Batch [600/938]                   Loss D: 0.5386, Loss G: 0.8134
# Epoch [10/50] Batch [800/938]                   Loss D: 0.5724, Loss G: 1.1279
# Epoch [11/50] Batch [0/938]                   Loss D: 0.5755, Loss G: 0.8732
# Epoch [11/50] Batch [200/938]                   Loss D: 0.5351, Loss G: 1.0726
# Epoch [11/50] Batch [400/938]                   Loss D: 0.6066, Loss G: 0.6189
# Epoch [11/50] Batch [600/938]                   Loss D: 0.6994, Loss G: 0.4408
# Epoch [11/50] Batch [800/938]                   Loss D: 0.5613, Loss G: 0.7339
# Epoch [12/50] Batch [0/938]                   Loss D: 0.6508, Loss G: 1.8589
# Epoch [12/50] Batch [200/938]                   Loss D: 0.5492, Loss G: 1.3305
# Epoch [12/50] Batch [400/938]                   Loss D: 0.5298, Loss G: 0.8009
# Epoch [12/50] Batch [600/938]                   Loss D: 0.5639, Loss G: 0.7516
# Epoch [12/50] Batch [800/938]                   Loss D: 0.5392, Loss G: 0.9154
# Epoch [13/50] Batch [0/938]                   Loss D: 0.5282, Loss G: 1.1833
# Epoch [13/50] Batch [200/938]                   Loss D: 0.5940, Loss G: 0.7678
# Epoch [13/50] Batch [400/938]                   Loss D: 0.5453, Loss G: 0.9840
# Epoch [13/50] Batch [600/938]                   Loss D: 0.5306, Loss G: 0.8621
# Epoch [13/50] Batch [800/938]                   Loss D: 0.5058, Loss G: 1.1369
# Epoch [14/50] Batch [0/938]                   Loss D: 0.5637, Loss G: 0.8346
# Epoch [14/50] Batch [200/938]                   Loss D: 0.5623, Loss G: 1.0299
# Epoch [14/50] Batch [400/938]                   Loss D: 0.5423, Loss G: 1.3416
# Epoch [14/50] Batch [600/938]                   Loss D: 0.5551, Loss G: 1.1210
# Epoch [14/50] Batch [800/938]                   Loss D: 0.5783, Loss G: 0.7850
# Epoch [15/50] Batch [0/938]                   Loss D: 0.5715, Loss G: 0.9474
# Epoch [15/50] Batch [200/938]                   Loss D: 0.6529, Loss G: 0.5270
# Epoch [15/50] Batch [400/938]                   Loss D: 0.5257, Loss G: 1.0900
# Epoch [15/50] Batch [600/938]                   Loss D: 0.6008, Loss G: 0.8875
# Epoch [15/50] Batch [800/938]                   Loss D: 0.5697, Loss G: 0.8546
# Epoch [16/50] Batch [0/938]                   Loss D: 0.6050, Loss G: 0.7435
# Epoch [16/50] Batch [200/938]                   Loss D: 0.5463, Loss G: 1.0876
# Epoch [16/50] Batch [400/938]                   Loss D: 0.6552, Loss G: 1.6644
# Epoch [16/50] Batch [600/938]                   Loss D: 0.5824, Loss G: 1.0761
# Epoch [16/50] Batch [800/938]                   Loss D: 0.6179, Loss G: 1.0044
# Epoch [17/50] Batch [0/938]                   Loss D: 0.6579, Loss G: 0.4908
# Epoch [17/50] Batch [200/938]                   Loss D: 0.5503, Loss G: 1.4077
# Epoch [17/50] Batch [400/938]                   Loss D: 0.5760, Loss G: 1.0101
# Epoch [17/50] Batch [600/938]                   Loss D: 0.5166, Loss G: 1.0170
# Epoch [17/50] Batch [800/938]                   Loss D: 0.5468, Loss G: 0.7958
# Epoch [18/50] Batch [0/938]                   Loss D: 0.6633, Loss G: 0.5298
# Epoch [18/50] Batch [200/938]                   Loss D: 0.6187, Loss G: 0.6148
# Epoch [18/50] Batch [400/938]                   Loss D: 0.5992, Loss G: 0.6721
# Epoch [18/50] Batch [600/938]                   Loss D: 0.5782, Loss G: 0.9522
# Epoch [18/50] Batch [800/938]                   Loss D: 0.6232, Loss G: 0.6721
# Epoch [19/50] Batch [0/938]                   Loss D: 0.5356, Loss G: 1.0847
# Epoch [19/50] Batch [200/938]                   Loss D: 0.6150, Loss G: 0.6058
# Epoch [19/50] Batch [400/938]                   Loss D: 0.6822, Loss G: 0.4969
# Epoch [19/50] Batch [600/938]                   Loss D: 0.5796, Loss G: 1.1433
# Epoch [19/50] Batch [800/938]                   Loss D: 0.6004, Loss G: 1.5963
# Epoch [20/50] Batch [0/938]                   Loss D: 0.5823, Loss G: 0.8036
# Epoch [20/50] Batch [200/938]                   Loss D: 0.5459, Loss G: 1.5053
# Epoch [20/50] Batch [400/938]                   Loss D: 0.4722, Loss G: 1.1155
# Epoch [20/50] Batch [600/938]                   Loss D: 0.5876, Loss G: 0.7463
# Epoch [20/50] Batch [800/938]                   Loss D: 0.6301, Loss G: 1.1001
# Epoch [21/50] Batch [0/938]                   Loss D: 0.5865, Loss G: 0.9756
# Epoch [21/50] Batch [200/938]                   Loss D: 0.5856, Loss G: 1.4853
# Epoch [21/50] Batch [400/938]                   Loss D: 0.5780, Loss G: 1.0467
# Epoch [21/50] Batch [600/938]                   Loss D: 0.5623, Loss G: 1.0868
# Epoch [21/50] Batch [800/938]                   Loss D: 0.5809, Loss G: 0.9710
# Epoch [22/50] Batch [0/938]                   Loss D: 0.5872, Loss G: 1.3552
# Epoch [22/50] Batch [200/938]                   Loss D: 0.5332, Loss G: 1.0586
# Epoch [22/50] Batch [400/938]                   Loss D: 0.5801, Loss G: 1.1042
# Epoch [22/50] Batch [600/938]                   Loss D: 0.5615, Loss G: 0.8608
# Epoch [22/50] Batch [800/938]                   Loss D: 0.6242, Loss G: 1.0336
# Epoch [23/50] Batch [0/938]                   Loss D: 0.5828, Loss G: 0.8004
# Epoch [23/50] Batch [200/938]                   Loss D: 0.5844, Loss G: 0.7652
# Epoch [23/50] Batch [400/938]                   Loss D: 0.5705, Loss G: 1.1874
# Epoch [23/50] Batch [600/938]                   Loss D: 0.6247, Loss G: 0.5420
# Epoch [23/50] Batch [800/938]                   Loss D: 0.5391, Loss G: 1.1178
# Epoch [24/50] Batch [0/938]                   Loss D: 0.5520, Loss G: 0.8566
# Epoch [24/50] Batch [200/938]                   Loss D: 0.5481, Loss G: 0.8588
# Epoch [24/50] Batch [400/938]                   Loss D: 0.5245, Loss G: 1.1057
# Epoch [24/50] Batch [600/938]                   Loss D: 0.5405, Loss G: 1.0366
# Epoch [24/50] Batch [800/938]                   Loss D: 0.5946, Loss G: 1.5188
# Epoch [25/50] Batch [0/938]                   Loss D: 0.5671, Loss G: 0.7176
# Epoch [25/50] Batch [200/938]                   Loss D: 0.5529, Loss G: 0.7809
# Epoch [25/50] Batch [400/938]                   Loss D: 0.5647, Loss G: 1.1164
# Epoch [25/50] Batch [600/938]                   Loss D: 0.5418, Loss G: 0.9292
# Epoch [25/50] Batch [800/938]                   Loss D: 0.5906, Loss G: 0.9446
# Epoch [26/50] Batch [0/938]                   Loss D: 0.5594, Loss G: 0.9074
# Epoch [26/50] Batch [200/938]                   Loss D: 0.5479, Loss G: 1.0928
# Epoch [26/50] Batch [400/938]                   Loss D: 0.5875, Loss G: 1.0526
# Epoch [26/50] Batch [600/938]                   Loss D: 0.5341, Loss G: 1.1865
# Epoch [26/50] Batch [800/938]                   Loss D: 0.5469, Loss G: 1.3947
# Epoch [27/50] Batch [0/938]                   Loss D: 0.6359, Loss G: 1.3630
# Epoch [27/50] Batch [200/938]                   Loss D: 0.6402, Loss G: 1.7503
# Epoch [27/50] Batch [400/938]                   Loss D: 0.5865, Loss G: 0.7909
# Epoch [27/50] Batch [600/938]                   Loss D: 0.5769, Loss G: 1.2487
# Epoch [27/50] Batch [800/938]                   Loss D: 0.5888, Loss G: 1.1392
# Epoch [28/50] Batch [0/938]                   Loss D: 0.5746, Loss G: 1.2778
# Epoch [28/50] Batch [200/938]                   Loss D: 0.6204, Loss G: 1.0318
# Epoch [28/50] Batch [400/938]                   Loss D: 0.6535, Loss G: 1.4407
# Epoch [28/50] Batch [600/938]                   Loss D: 0.6274, Loss G: 0.5837
# Epoch [28/50] Batch [800/938]                   Loss D: 0.5651, Loss G: 0.9803
# Epoch [29/50] Batch [0/938]                   Loss D: 0.5867, Loss G: 1.5642
# Epoch [29/50] Batch [200/938]                   Loss D: 0.5384, Loss G: 0.9778
# Epoch [29/50] Batch [400/938]                   Loss D: 0.5902, Loss G: 1.3094
# Epoch [29/50] Batch [600/938]                   Loss D: 0.5169, Loss G: 0.9640
# Epoch [29/50] Batch [800/938]                   Loss D: 0.5432, Loss G: 0.9039
# Epoch [30/50] Batch [0/938]                   Loss D: 0.5543, Loss G: 1.0793
# Epoch [30/50] Batch [200/938]                   Loss D: 0.5318, Loss G: 1.3542
# Epoch [30/50] Batch [400/938]                   Loss D: 0.5654, Loss G: 1.1112
# Epoch [30/50] Batch [600/938]                   Loss D: 0.6259, Loss G: 0.7143
# Epoch [30/50] Batch [800/938]                   Loss D: 0.5547, Loss G: 0.7111
# Epoch [31/50] Batch [0/938]                   Loss D: 0.5440, Loss G: 0.9694
# Epoch [31/50] Batch [200/938]                   Loss D: 0.6133, Loss G: 0.7829
# Epoch [31/50] Batch [400/938]                   Loss D: 0.5404, Loss G: 1.2674
# Epoch [31/50] Batch [600/938]                   Loss D: 0.5308, Loss G: 1.1141
# Epoch [31/50] Batch [800/938]                   Loss D: 0.6392, Loss G: 0.7106
# Epoch [32/50] Batch [0/938]                   Loss D: 0.4909, Loss G: 1.3431
# Epoch [32/50] Batch [200/938]                   Loss D: 0.5658, Loss G: 0.8865
# Epoch [32/50] Batch [400/938]                   Loss D: 0.5431, Loss G: 0.9003
# Epoch [32/50] Batch [600/938]                   Loss D: 0.5936, Loss G: 0.9062
# Epoch [32/50] Batch [800/938]                   Loss D: 0.5939, Loss G: 0.8883
# Epoch [33/50] Batch [0/938]                   Loss D: 0.6182, Loss G: 0.6041
# Epoch [33/50] Batch [200/938]                   Loss D: 0.5890, Loss G: 1.3660
# Epoch [33/50] Batch [400/938]                   Loss D: 0.5593, Loss G: 1.3415
# Epoch [33/50] Batch [600/938]                   Loss D: 0.5199, Loss G: 0.9738
# Epoch [33/50] Batch [800/938]                   Loss D: 0.5857, Loss G: 1.0467
# Epoch [34/50] Batch [0/938]                   Loss D: 0.5704, Loss G: 1.3164
# Epoch [34/50] Batch [200/938]                   Loss D: 0.5342, Loss G: 1.0361
# Epoch [34/50] Batch [400/938]                   Loss D: 0.5858, Loss G: 0.9937
# Epoch [34/50] Batch [600/938]                   Loss D: 0.6589, Loss G: 0.6159
# Epoch [34/50] Batch [800/938]                   Loss D: 0.5528, Loss G: 0.7818
# Epoch [35/50] Batch [0/938]                   Loss D: 0.5713, Loss G: 1.3514
# Epoch [35/50] Batch [200/938]                   Loss D: 0.5540, Loss G: 0.8037
# Epoch [35/50] Batch [400/938]                   Loss D: 0.5986, Loss G: 1.2793
# Epoch [35/50] Batch [600/938]                   Loss D: 0.6367, Loss G: 0.5866
# Epoch [35/50] Batch [800/938]                   Loss D: 0.6246, Loss G: 1.5946
# Epoch [36/50] Batch [0/938]                   Loss D: 0.5557, Loss G: 0.7755
# Epoch [36/50] Batch [200/938]                   Loss D: 0.5346, Loss G: 0.9526
# Epoch [36/50] Batch [400/938]                   Loss D: 0.5579, Loss G: 0.7948
# Epoch [36/50] Batch [600/938]                   Loss D: 0.5739, Loss G: 0.8341
# Epoch [36/50] Batch [800/938]                   Loss D: 0.5510, Loss G: 1.0051
# Epoch [37/50] Batch [0/938]                   Loss D: 0.5857, Loss G: 1.1962
# Epoch [37/50] Batch [200/938]                   Loss D: 0.5796, Loss G: 1.1468
# Epoch [37/50] Batch [400/938]                   Loss D: 0.5097, Loss G: 0.9248
# Epoch [37/50] Batch [600/938]                   Loss D: 0.5569, Loss G: 1.2110
# Epoch [37/50] Batch [800/938]                   Loss D: 0.5721, Loss G: 0.9702
# Epoch [38/50] Batch [0/938]                   Loss D: 0.5319, Loss G: 1.0485
# Epoch [38/50] Batch [200/938]                   Loss D: 0.5570, Loss G: 1.2067
# Epoch [38/50] Batch [400/938]                   Loss D: 0.5889, Loss G: 0.8276
# Epoch [38/50] Batch [600/938]                   Loss D: 0.5608, Loss G: 0.8170
# Epoch [38/50] Batch [800/938]                   Loss D: 0.5686, Loss G: 0.9481
# Epoch [39/50] Batch [0/938]                   Loss D: 0.5361, Loss G: 1.1862
# Epoch [39/50] Batch [200/938]                   Loss D: 0.5277, Loss G: 1.1239
# Epoch [39/50] Batch [400/938]                   Loss D: 0.5339, Loss G: 1.0385
# Epoch [39/50] Batch [600/938]                   Loss D: 0.5910, Loss G: 1.3396
# Epoch [39/50] Batch [800/938]                   Loss D: 0.6275, Loss G: 0.8791
# Epoch [40/50] Batch [0/938]                   Loss D: 0.5901, Loss G: 0.7964
# Epoch [40/50] Batch [200/938]                   Loss D: 0.5967, Loss G: 1.1538
# Epoch [40/50] Batch [400/938]                   Loss D: 0.5360, Loss G: 0.9280
# Epoch [40/50] Batch [600/938]                   Loss D: 0.5625, Loss G: 1.1586
# Epoch [40/50] Batch [800/938]                   Loss D: 0.5240, Loss G: 1.0385
# Epoch [41/50] Batch [0/938]                   Loss D: 0.5448, Loss G: 0.9462
# Epoch [41/50] Batch [200/938]                   Loss D: 0.6021, Loss G: 1.5008
# Epoch [41/50] Batch [400/938]                   Loss D: 0.5364, Loss G: 1.1120
# Epoch [41/50] Batch [600/938]                   Loss D: 0.5348, Loss G: 1.1352
# Epoch [41/50] Batch [800/938]                   Loss D: 0.5983, Loss G: 0.9178
# Epoch [42/50] Batch [0/938]                   Loss D: 0.6039, Loss G: 0.9565
# Epoch [42/50] Batch [200/938]                   Loss D: 0.5785, Loss G: 1.1320
# Epoch [42/50] Batch [400/938]                   Loss D: 0.5272, Loss G: 1.3292
# Epoch [42/50] Batch [600/938]                   Loss D: 0.5153, Loss G: 0.7842
# Epoch [42/50] Batch [800/938]                   Loss D: 0.5511, Loss G: 0.9396
# Epoch [43/50] Batch [0/938]                   Loss D: 0.6333, Loss G: 1.0698
# Epoch [43/50] Batch [200/938]                   Loss D: 0.5057, Loss G: 1.0732
# Epoch [43/50] Batch [400/938]                   Loss D: 0.5423, Loss G: 1.2736
# Epoch [43/50] Batch [600/938]                   Loss D: 0.5638, Loss G: 1.0042
# Epoch [43/50] Batch [800/938]                   Loss D: 0.5870, Loss G: 1.0099
# Epoch [44/50] Batch [0/938]                   Loss D: 0.6097, Loss G: 0.7535
# Epoch [44/50] Batch [200/938]                   Loss D: 0.5698, Loss G: 1.5206
# Epoch [44/50] Batch [400/938]                   Loss D: 0.5149, Loss G: 1.1453
# Epoch [44/50] Batch [600/938]                   Loss D: 0.5181, Loss G: 1.0309
# Epoch [44/50] Batch [800/938]                   Loss D: 0.5610, Loss G: 1.1526
# Epoch [45/50] Batch [0/938]                   Loss D: 0.6037, Loss G: 0.8776
# Epoch [45/50] Batch [200/938]                   Loss D: 0.5205, Loss G: 1.0585
# Epoch [45/50] Batch [400/938]                   Loss D: 0.6510, Loss G: 1.4660
# Epoch [45/50] Batch [600/938]                   Loss D: 0.5328, Loss G: 1.4649
# Epoch [45/50] Batch [800/938]                   Loss D: 0.6065, Loss G: 1.2520
# Epoch [46/50] Batch [0/938]                   Loss D: 0.5419, Loss G: 1.5949
# Epoch [46/50] Batch [200/938]                   Loss D: 0.5780, Loss G: 1.2426
# Epoch [46/50] Batch [400/938]                   Loss D: 0.5849, Loss G: 1.0466
# Epoch [46/50] Batch [600/938]                   Loss D: 0.5700, Loss G: 1.2255
# Epoch [46/50] Batch [800/938]                   Loss D: 0.5949, Loss G: 1.3671
# Epoch [47/50] Batch [0/938]                   Loss D: 0.5031, Loss G: 1.2509
# Epoch [47/50] Batch [200/938]                   Loss D: 0.5997, Loss G: 0.8144
# Epoch [47/50] Batch [400/938]                   Loss D: 0.4897, Loss G: 1.0265
# Epoch [47/50] Batch [600/938]                   Loss D: 0.5846, Loss G: 1.1319
# Epoch [47/50] Batch [800/938]                   Loss D: 0.6133, Loss G: 0.8172
# Epoch [48/50] Batch [0/938]                   Loss D: 0.5443, Loss G: 1.0237
# Epoch [48/50] Batch [200/938]                   Loss D: 0.5825, Loss G: 1.1372
# Epoch [48/50] Batch [400/938]                   Loss D: 0.6409, Loss G: 1.7919
# Epoch [48/50] Batch [600/938]                   Loss D: 0.5217, Loss G: 1.1591
# Epoch [48/50] Batch [800/938]                   Loss D: 0.5853, Loss G: 0.8563
# Epoch [49/50] Batch [0/938]                   Loss D: 0.5291, Loss G: 1.1831
# Epoch [49/50] Batch [200/938]                   Loss D: 0.5255, Loss G: 0.8500
# Epoch [49/50] Batch [400/938]                   Loss D: 0.5637, Loss G: 1.0057
# Epoch [49/50] Batch [600/938]                   Loss D: 0.5471, Loss G: 0.9513
# Epoch [49/50] Batch [800/938]                   Loss D: 0.5957, Loss G: 0.8021
# 🎉 Training complete. Check 'gan_images/' for generated digits.
